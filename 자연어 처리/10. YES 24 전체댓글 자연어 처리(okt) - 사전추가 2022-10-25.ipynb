# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib
import re
import string
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from nltk.corpus import stopwords  
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from wordcloud import WordCloud
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False
from konlpy.tag import Okt
from pykospacing import Spacing
from collections import Counter
import random
from tqdm import tqdm, trange
import time
from collections import Counter
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from collections import Counter
import pytagcloud 
import glob  
import sys
import openpyxl
from PIL import Image

# %% [markdown]
# ### 데이터 파일 합치기

# %%
DATA_IN_PATH="C:/python/yes24/" #최윤지 깃허브 경로
FileName='yes_url_'
df1=pd.read_csv(DATA_IN_PATH+FileName+'01.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df1))
df2=pd.read_csv(DATA_IN_PATH+FileName+'02.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df2))
df3=pd.read_csv(DATA_IN_PATH+FileName+'03.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df3))
df4=pd.read_csv(DATA_IN_PATH+FileName+'04.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df4))
df5=pd.read_csv(DATA_IN_PATH+FileName+'05.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df5))
df6=pd.read_csv(DATA_IN_PATH+FileName+'06.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df6))
df7=pd.read_csv(DATA_IN_PATH+FileName+'07.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df7))
df8=pd.read_csv(DATA_IN_PATH+FileName+'08.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df8))
df9=pd.read_csv(DATA_IN_PATH+FileName+'09.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df9))
df10=pd.read_csv(DATA_IN_PATH+FileName+'10.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df10))
df11=pd.read_csv(DATA_IN_PATH+FileName+'11.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df11))
df12=pd.read_csv(DATA_IN_PATH+FileName+'12.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df12))
df13=pd.read_csv(DATA_IN_PATH+FileName+'13.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df13))
# Out:
# 21
# 15
# 69
# 41
# 8
# 55
# 45
# 13
# 57
# 7
# 65
# 7
# 1

# %%
import pandas as pd
from glob import glob

file_names = glob("C:/python/yes24/*.csv") #폴더 내의 모든 csv파일 목록을 불러온다
total = pd.DataFrame() #빈 데이터프레임 하나를 생성한다

for file_name in file_names:
    temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
    total = pd.concat([total, temp]) #전체 데이터프레임에 추가하여 넣는다

total.to_csv("C:/python/yes24/total.csv")
# Out:
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다
# C:\Users\nirae\AppData\Local\Temp\ipykernel_257868\3856532443.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(file_name, sep='구분자', encoding='utf-8') #csv파일을 하나씩 열어 임시 데이터프레임으로 생성한다

# %%
df=pd.read_csv("C:/python/yes24/yes24_review_total.csv",header=0,sep=',') #quoting=3 쌍따옴표 무시
print(len(df))
# Out:
# 404

# %% [markdown]
# ### 전처리 데이터 크롤링

# %%
DATA_IN_PATH="C:/Users/nirae/Desktop/주간프로젝트 깃허브 폴더(최종)/크롤링/data/" #최윤지 깃허브 경로

FileName='yes24_review_total'

# %%
df=pd.read_csv(DATA_IN_PATH+FileName+'.csv',header=0,sep=',') #quoting=3 쌍따옴표 무시
df.head()
# Out:
#    Unnamed: 0                                             Review
# 0           0  기대보다 웹툰에서 전투신이라던가 캐릭터들의 매력 그리고 몹들까지 잘 살린거 같아서 ...
# 1           1  전지적 독자 시점 1권 초판 한정 부록 포함입니다이제 막 시작되는 부분이라 엥......
# 2           2  "에이템포미디어에서 출간 된 싱숑 작가님의 작품을 슬리피-C 작가님이 웹툰화한 작품...
# 3           3  "전지적 독자시점 1권 싱숑원작 작품입니다.주위의 추천으로 구매하게 된 책입니다.엄...
# 4           4  "원작이 한창 연재 중에는 소문만 들었다가 완결 난 뒤에 친구의 추천으로 읽게 된 ...

# %%
#데이터개수
print('데이터개수:{}'.format(len(df)))
# Out:
# 데이터개수:404

# %%
#각 리뷰의 문자 길이 분포
df_length=df['Review'].apply(len)
df_length.head()
# Out:
# 0    206
# 1    297
# 2    222
# 3    195
# 4    211
# Name: Review, dtype: int64

# %%
plt.figure(figsize=(12,5))#그래프 이미지 사이즈 선언
plt.hist(df_length,bins=200, color='r',alpha=0.5, label='word') #히스토그램
plt.yscale('log')
plt.title('log-histogram of length of Review')
plt.xlabel('length of Review')
plt.ylabel('Number of Review')


#############
#YES 24 리뷰문자 길이는 평균적으로 300이하가 많음
#############
# Out:
# Text(0, 0.5, 'Number of Review')

# %%
print('리뷰문자 최소 길이:{}'.format(np.min(df_length)))
print('리뷰문자 최대 길이:{}'.format(np.max(df_length))) 
print('리뷰문자 평균 길이:{:.2f}'.format(np.mean(df_length)))
print('리뷰문자 표준 편차 길이:{:.2f}'.format(np.std(df_length)))
print('리뷰문자 중앙값:{}'.format(np.median(df_length)))
print('리뷰문자 1사분위 길이:{}'.format(np.percentile(df_length,25)))
print('리뷰문자 3사분위 길이:{}'.format(np.percentile(df_length,75)))
# Out:
# 리뷰문자 최소 길이:174
# 리뷰문자 최대 길이:739
# 리뷰문자 평균 길이:257.77
# 리뷰문자 표준 편차 길이:94.12
# 리뷰문자 중앙값:222.5
# 리뷰문자 1사분위 길이:204.0
# 리뷰문자 3사분위 길이:275.75

# %%
cloud = WordCloud(font_path='malgun', width=800, height=400).generate("".join(df['Review']))
plt.figure(figsize=(15,10))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Review        0
# dtype: int64

# %%
#한글, 숫자 표현만 남기기
def extract_word(text):
    hangul = re.compile('[^0-9가-힣]') 
    result = hangul.sub(' ', text) 
    return result

# %%
print("Before Extraction : ",df['Review'][96])
print("After Extraction : ", extract_word(df['Review'][96]))

print("Before Extraction : ",df['Review'][103])
print("After Extraction : ", extract_word(df['Review'][103]))
# Out:
remove_one_word = [x for x in words if len(x)>1 or x=="글"]
len(remove_one_word)
# Out:
# 25221

# %%
with open('stopwords.txt', 'r') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")
remove_stopwords = [x for x in remove_one_word if x not in stopwords]
len(remove_stopwords)
# Out:
# 14008

# %%
Counter(remove_stopwords).most_common()
# Out:
# [('웹툰', 557),
#  ('독자', 368),
#  ('소설', 333),
#  ('구매', 270),
#  ('단행본', 227),
#  ('전지적', 217),
#  ('그림', 183),
#  ('원작', 178),
#  ('작품', 137),
#  ('내용', 123),
#  ('전독시', 118),
#  ('재밌다', 116),
#  ('싱숑', 109),
#  ('소장', 109),
#  ('완결', 107),
#  ('표지', 93),
#  ('리뷰', 92),
#  ('이야기', 89),
#  ('작가', 87),
#  ('연재', 82),
#  ('캐릭터', 81),
#  ('좋아하다', 75),
#  ('사람', 75),
#  ('만화', 72),
#  ('세계', 72),
#  ('초판', 70),
#  ('기대', 69),
#  ('재미있다', 69),
#  ('주인공', 67),
#  ('빨리', 66),
#  ('기다리다', 64),
#  ('작화', 63),
#  ('마음', 63),
#  ('슬리피', 62),
#  ('카드', 60),
#  ('아쉽다', 58),
#  ('각색', 58),
#  ('글', 56),
#  ('구성', 56),
#  ('인기', 55),
#  ('처음', 52),
#  ('종이', 51),
#  ('부록', 48),
#  ('궁금하다', 48),
#  ('스토리', 47),
#  ('웹소설', 45),
#  ('기대하다', 45),
#  ('시작', 44),
#  ('그리다', 44),
#  ('취향', 43),
#  ('모으다', 42),
#  ('추천', 40),
#  ('회귀', 40),
#  ('살리다', 39),
#  ('다르다', 39),
#  ('새롭다', 39),
#  ('판타지', 39),
#  ('미디어', 38),
#  ('예쁘다', 38),
#  ('세트', 37),
#  ('김독자', 37),
#  ('에이템포', 36),
#  ('인물', 36),
#  ('재질', 36),
#  ('현실', 35),
#  ('상상', 34),
#  ('구입', 34),
#  ('얼른얼른', 34),
#  ('전개', 33),
#  ('사다', 33),
#  ('초반', 32),
#  ('한정판', 32),
#  ('세상', 31),
#  ('매력', 30),
#  ('유명하다', 30),
#  ('잘생기다', 30),
#  ('네이버', 29),
#  ('소장용', 29),
#  ('기분', 29),
#  ('얼른', 29),
#  ('유중혁', 28),
#  ('유일하다', 28),
#  ('느끼다', 27),
#  ('한정', 27),
#  ('편집', 27),
#  ('에디션', 27),
#  ('즐겁다', 26),
#  ('결말', 26),
#  ('중혁', 26),
#  ('탄탄하다', 26),
#  ('드디어', 26),
#  ('벌레', 25),
#  ('괜찮다', 25),
#  ('재미', 25),
#  ('표현', 25),
#  ('스트랩', 25),
#  ('소식', 24),
#  ('지르다', 24),
#  ('이쁘다', 24),
#  ('특전', 24),
#  ('스페셜', 24),
#  ('어여', 24),
#  ('만화책', 23),
#  ('확실하다', 23),
#  ('10년', 23),
#  ('가격', 23),
#  ('바라다', 23),
#  ('만족하다', 23),
#  ('포함', 22),
#  ('지하철', 22),
#  ('퀄리티', 22),
#  ('장르', 22),
#  ('만족스럽다', 22),
#  ('야하다', 21),
#  ('빠지다', 21),
#  ('설화', 21),
#  ('출판사', 21),
#  ('시리즈', 20),
#  ('평균', 20),
#  ('뜨다', 20),
#  ('런가', 19),
#  ('아무튼', 19),
#  ('행복하다', 19),
#  ('사랑', 19),
#  ('만들다', 19),
#  ('배송', 19),
#  ('내주다', 19),
#  ('차다', 19),
#  ('품절', 19),
#  ('책장', 19),
#  ('최고', 18),
#  ('아무래도', 18),
#  ('그려지다', 18),
#  ('해당', 18),
#  ('떡밥', 18),
#  ('회수', 18),
#  ('버리다', 18),
#  ('장본', 18),
#  ('빠르다', 18),
#  ('스페셜에디션', 18),
#  ('존재', 17),
#  ('살아나다', 17),
#  ('물들다', 17),
#  ('라면', 17),
#  ('상황', 17),
#  ('신경', 17),
#  ('깔끔하다', 17),
#  ('스크롤', 17),
#  ('아깝다', 17),
#  ('너무나', 17),
#  ('이르다', 16),
#  ('리얼', 16),
#  ('후회', 16),
#  ('로는', 16),
#  ('주행', 16),
#  ('조회', 16),
#  ('시나리오', 16),
#  ('정희원', 16),
#  ('냄새', 16),
#  ('항상', 16),
#  ('나혼', 16),
#  ('투신', 15),
#  ('나름', 15),
#  ('소재', 15),
#  ('챙기다', 15),
#  ('기다', 15),
#  ('열심히', 15),
#  ('에선', 15),
#  ('주문', 15),
#  ('연출', 15),
#  ('발간', 15),
#  ('스포일러', 15),
#  ('증명사진', 15),
#  ('성품', 15),
#  ('주의', 14),
#  ('채우다', 14),
#  ('유명', 14),
#  ('굉장하다', 14),
#  ('장편', 14),
#  ('벨벳', 14),
#  ('귀엽다', 14),
#  ('멸살법', 14),
#  ('기억', 14),
#  ('가치', 14),
#  ('살다', 14),
#  ('벌써', 14),
#  ('사은품', 13),
#  ('이니', 13),
#  ('구현', 13),
#  ('뭔가', 13),
#  ('에서는', 13),
#  ('죽이다', 13),
#  ('묻다', 13),
#  ('살짝', 13),
#  ('편이', 13),
#  ('꾸준하다', 13),
#  ('준비', 13),
#  ('아들', 13),
#  ('아무', 13),
#  ('제목', 13),
#  ('확인', 13),
#  ('아름답다', 13),
#  ('투명', 13),
#  ('라던가', 12),
#  ('관심', 12),
#  ('선택', 12),
#  ('태어나다', 12),
#  ('놓치다', 12),
#  ('이유', 12),
#  ('감탄', 12),
#  ('들어서다', 12),
#  ('유상아', 12),
#  ('걱정', 12),
#  ('작성', 12),
#  ('들어가다', 12),
#  ('감사하다', 12),
#  ('칼라', 12),
#  ('동네', 12),
#  ('요다음', 12),
#  ('넘어가다', 11),
#  ('기도', 11),
#  ('엄청나다', 11),
#  ('에서만', 11),
#  ('저격', 11),
#  ('독특하다', 11),
#  ('만지다', 11),
#  ('편하다', 11),
#  ('아직도', 11),
#  ('힘들다', 11),
#  ('납득', 11),
#  ('믿다', 11),
#  ('도깨비', 11),
#  ('눈물', 11),
#  ('끝내다', 11),
#  ('와중', 11),
#  ('훌륭하다', 11),
#  ('로서', 11),
#  ('나가다', 11),
#  ('보아', 11),
#  ('댓글', 11),
#  ('하루', 11),
#  ('볼때', 11),
#  ('안나', 11),
#  ('아마', 11),
#  ('해외', 11),
#  ('분위기', 11),
#  ('단행', 11),
#  ('형식', 11),
#  ('쓸다', 11),
#  ('다행', 11),
#  ('만족', 11),
#  ('박스', 11),
#  ('스티커', 11),
#  ('일러스트', 11),
#  ('흡입', 10),
#  ('찰나', 10),
#  ('일정', 10),
#  ('금액', 10),
#  ('기회', 10),
#  ('주위', 10),
#  ('활자', 10),
#  ('생생하다', 10),
#  ('두르다', 10),
#  ('못내', 10),
#  ('현재', 10),
#  ('남자', 10),
#  ('몰입', 10),
#  ('생명', 10),
#  ('신기하다', 10),
#  ('과정', 10),
#  ('뛰어나다', 10),
#  ('외전', 10),
#  ('독쟈', 10),
#  ('멈추다', 10),
#  ('유료', 10),
#  ('어쩜', 10),
#  ('당연하다', 10),
#  ('으로의', 10),
#  ('사고', 10),
#  ('결제', 10),
#  ('횟수', 10),
#  ('149회', 10),
#  ('9회', 10),
#  ('08', 10),
#  ('그날', 10),
#  ('동시', 10),
#  ('메인', 10),
#  ('삽화가', 10),
#  ('재탕', 10),
#  ('강추', 10),
#  ('이라서', 10),
#  ('사용', 10),
#  ('작다', 10),
#  ('인쇄', 10),
#  ('솔직하다', 10),
#  ('방대하다', 10),
#  ('길이', 10),
#  ('포토', 10),
#  ('전자책', 10),
#  ('게임', 10),
#  ('이니까', 10),
#  ('일반', 10),
#  ('굿즈', 10),
#  ('보드', 10),
#  ('발매', 9),
#  ('몰다', 9),
#  ('소문', 9),
#  ('동봉', 9),
#  ('상품', 9),
#  ('높다', 9),
#  ('포스터', 9),
#  ('빵빵', 9),
#  ('애가', 9),
#  ('내지', 9),
#  ('안보', 9),
#  ('출판', 9),
#  ('응원', 9),
#  ('발견', 9),
#  ('갈다', 9),
#  ('실물', 9),
#  ('도착', 9),
#  ('더하다', 9),
#  ('많아지다', 9),
#  ('얼굴', 9),
#  ('뜯다', 9),
#  ('한참', 9),
#  ('느껴지다', 9),
#  ('그녀', 9),
#  ('케이스', 9),
#  ('엽서', 9),
#  ('멋있다', 9),
#  ('공필두', 9),
#  ('점점', 9),
#  ('듣다', 8),
#  ('장난', 8),
#  ('물리다', 8),
#  ('부대끼다', 8),
#  ('공간', 8),
#  ('맞추다', 8),
#  ('본도', 8),
#  ('너무나도', 8),
#  ('화가', 8),
#  ('에서도', 8),
#  ('팔다', 8),
#  ('사서', 8),
#  ('스포', 8),
#  ('대비', 8),
#  ('뽑다', 8),
#  ('만에', 8),
#  ('편의', 8),
#  ('부드럽다', 8),
#  ('멀다', 8),
#  ('캐디', 8),
#  ('이후', 8),
#  ('중이', 8),
#  ('분량', 8),
#  ('인지', 8),
#  ('늦다', 8),
#  ('흥미롭다', 8),
#  ('과거', 8),
#  ('상상력', 8),
#  ('코믹스', 8),
#  ('눈부시다', 8),
#  ('광채', 8),
#  ('피어', 8),
#  ('물러나다', 8),
#  ('주저', 8),
#  ('슬립', 8),
#  ('희원', 8),
#  ('영상', 7),
#  ('수도', 7),
#  ('특성', 7),
#  ('예전', 7),
#  ('걸리다', 7),
#  ('달리다', 7),
#  ('상태', 6),
#  ('더욱', 6),
#  ('보관', 6),
#  ('이기다', 6),
#  ('분들', 6),
#  ('빨르다', 6),
#  ('무지', 6),
#  ('마지막', 6),
#  ('원하다', 6),
#  ('디자인', 6),
#  ('다양하다', 6),
#  ('네이버웹툰', 6),
#  ('홀더', 6),
#  ('알차다', 6),
#  ('만나다', 6),
#  ('이벤트', 6),
#  ('미루다', 6),
#  ('간직', 6),
#  ('감당', 6),
#  ('로프트', 6),
#  ('새삼', 5),
#  ('실제', 5),
#  ('잘살다', 5),
#  ('물이', 5),
#  ('헷갈리다', 5),
#  ('알아차리다', 5),
#  ('쉽다', 5),
#  ('저서', 5),
#  ('아예', 5),
#  ('포스트잇', 5),
#  ('붙이다', 5),
#  ('큼직하다', 5),
#  ('마찬가지', 5),
#  ('보시', 5),
#  ('호불호', 5),
#  ('분위', 5),
#  ('이미지', 5),
#  ('입부', 5),
#  ('지켜보다', 5),
#  ('어쩌면', 5),
#  ('신선하다', 5),
#  ('무감', 5),
#  ('뽑히다', 5),
#  ('적용', 5),
#  ('건데', 5),
#  ('너머', 5),
#  ('완소', 5),
#  ('권수', 5),
#  ('압박', 5),
#  ('화수', 5),
#  ('소설화수', 5),
#  ('십년', 5),
#  ('술술', 5),
#  ('째지다', 5),
#  ('에만', 5),
#  ('버젓이', 5),
#  ('파랗다', 5),
#  ('강조', 5),
#  ('대대손손', 5),
#  ('자라다', 5),
#  ('칭찬', 5),
#  ('집어넣다', 5),
#  ('힘겹다', 5),
#  ('보이', 5),
#  ('암담하다', 5),
#  ('장장', 5),
#  ('500', 5),
#  ('벽돌', 5),
#  ('거뜬하다', 5),
#  ('텐데', 5),
#  ('대체', 5),
#  ('설레다', 5),
#  ('갓띵작', 5),
#  ('배열', 5),
#  ('하잖슴', 5),
#  ('안함', 5),
#  ('존잘', 5),
#  ('22일', 5),
#  ('방식', 5),
#  ('사기', 5),
#  ('투하', 5),
#  ('벗어나다', 5),
#  ('웹소', 5),
#  ('따라가다', 5),
#  ('눈앞', 5),
#  ('볼떄', 5),
#  ('흥미', 5),
#  ('편도', 5),
#  ('디테', 5),
#  ('그리기', 5),
#  ('수고', 5),
#  ('매니아', 5),
#  ('결심', 5),
#  ('왜냐면', 5),
#  ('지나', 5),
#  ('망하다', 5),
#  ('인식', 5),
#  ('박하다', 5),
#  ('메세지', 5),
#  ('일상생활', 5),
#  ('이를', 5),
#  ('비롯', 5),
#  ('고맙다', 5),
#  ('주어', 5),
#  ('사랑스럽다', 5),
#  ('허전하다', 5),
#  ('말랑하다', 5),
#  ('나타나다', 5),
#  ('영향', 5),
#  ('챡챡', 5),
#  ('하얗다', 5),
#  ('녀석', 5),
#  ('기특하다', 5),
#  ('지식', 5),
#  ('머릿속', 5),
#  ('계산', 5),
#  ('고요', 5),
#  ('친분', 5),
#  ('반응', 5),
#  ('거고', 5),
#  ('천사', 5),
#  ('한국', 5),
#  ('직장인', 5),
#  ('취업', 5),
#  ('공감', 5),
#  ('설정', 5),
#  ('기발하다', 5),
#  ('전환', 5),
#  ('전형', 5),
#  ('진지하다', 5),
#  ('코믹', 5),
#  ('완급', 5),
#  ('조절', 5),
#  ('출근', 5),
#  ('도중', 5),
#  ('차례', 5),
#  ('미션', 5),
#  ('수행', 5),
#  ('미래', 5),
#  ('희망', 5),
#  ('우울하다', 5),
#  ('국면', 5),
#  ('헤치다', 5),
#  ('용다', 5),
#  ('영웅', 5),
#  ('짜릿하다', 5),
#  ('동경', 5),
#  ('모해', 5),
#  ('마주', 5),
#  ('절때', 5),
#  ('존버', 5),
#  ('사정', 5),
#  ('의치', 5),
#  ('드라마', 5),
#  ('애니', 5),
#  ('의문', 5),
#  ('의사', 5),
#  ('펴다', 5),
#  ('단점', 5),
#  ('줄거리', 5),
#  ('소개', 5),
#  ('해드리다', 5),
#  ('매일', 5),
#  ('업데이트', 5),
#  ('한장', 5),
#  ('넘겨보다', 5),
#  ('재탕하다', 5),
#  ('연결', 5),
#  ('혼란', 5),
#  ('해소', 5),
#  ('쑥쑥', 5),
#  ('읽히다', 5),
#  ('가리다', 5),
#  ('다루다', 5),
#  ('치가', 5),
#  ('자이언트', 5),
#  ('비밀', 5),
#  ('비현실적', 5),
#  ('오밀조밀', 5),
#  ('모이다', 5),
#  ('남아', 5),
#  ('찍다', 5),
#  ('우리나라', 5),
#  ('국내', 5),
#  ('이루어지다', 5),
#  ('닿다', 5),
#  ('가독성', 5),
#  ('불어', 5),
#  ('주요', 5),
#  ('효과', 5),
#  ('말고도', 5),
#  ('이런저런', 5),
#  ('화질', 5),
#  ('씁쓸하다', 5),
#  ('임팩트', 5),
#  ('존멋', 5),
#  ('차이', 5),
#  ('꼬박', 5),
#  ('금전', 5),
#  ('세로', 5),
#  ('가로', 5),
#  ('마무리', 5),
#  ('김컴', 5),
#  ('지장', 5),
#  ('간행', 5),
#  ('화만', 5),
#  ('적정하다', 5),
#  ('비닐', 5),
#  ('잉크', 5),
#  ('맡다', 5),
#  ('내부', 5),
#  ('두고두고', 5),
#  ('멋지다', 5),
#  ('그대로', 5),
#  ('예약판매', 5),
#  ('예정', 5),
#  ('기쁘다', 5),
#  ('적다', 5),
#  ('펼쳐지다', 5),
#  ('이어지다', 5),
#  ('선착순', 5),
#  ('자국', 5),
#  ('아프다', 5),
#  ('감격', 5),
#  ('포카', 5),
#  ('가득', 5),
#  ('일지', 5),
#  ('가능하다', 5),
#  ('예약', 5),
#  ('빼다', 5),
#  ('달다', 5),
#  ('질도', 5),
#  ('치고', 5),
#  ('속도', 5),
#  ('언제나', 5),
#  ('인거', 5),
#  ('모서리', 5),
#  ('찢어지다', 5),
#  ('나혼랩', 5),
#  ('사르다', 5),
#  ('서서히', 5),
#  ('프롤로그', 5),
#  ('각성', 5),
#  ('성장하다', 5),
#  ('프리미엄', 5),
#  ('굿즈들', 5),
#  ('꺼내다', 5),
#  ('이해', 5),
#  ('고급', 5),
#  ('불구', 5),
#  ('쭈욱', 5),
#  ('정발', 5),
#  ('무척', 4),
#  ('독시', 4),
#  ('짜다', 4),
#  ('참여', 4),
#  ('해봤다', 4),
#  ('이기도', 4),
#  ('무조건', 4),
#  ('따다', 4),
#  ('이든', 4),
#  ('수량', 4),
#  ('싱크로', 4),
#  ('다행하다', 4),
#  ('딱하다', 4),
#  ('불리다', 4),
#  ('예스', 4),
#  ('까지의', 4),
#  ('색다르다', 4),
#  ('컬러', 4),
#  ('등장인물', 4),
#  ('비싸다', 4),
#  ('상당하다', 4),
#  ('몰입도', 4),
#  ('미치다', 4),
#  ('보드랍다', 4),
#  ('하고프다', 4),
#  ('무협', 4),
#  ('얘기', 4),
#  ('권한', 4),
#  ('박수', 4),
#  ('욕심', 4),
#  ('연령', 4),
#  ('삽화', 4),
#  ('평법', 4),
#  ('자주', 4),
#  ('에게도', 4),
#  ('부담', 4),
#  ('개발', 4),
#  ('식히다', 4),
#  ('조금씩', 4),
#  ('중지', 4),
#  ('퐁퐁', 4),
#  ('인게', 4),
#  ('신기', 4),
#  ('방기', 4),
#  ('옛날', 4),
#  ('부탁', 4),
#  ('시도', 4),
#  ('구한', 4),
#  ('관계', 4),
#  ('빙의', 4),
#  ('장악', 4),
#  ('과장', 4),
#  ('기해', 4),
#  ('복수', 4),
#  ('그걸', 4),
#  ('간다', 4),
#  ('판무', 4),
#  ('현장', 4),
#  ('특기', 4),
#  ('읽을떄', 4),
#  ('봉투', 4),
#  ('본격', 4),
#  ('점차', 4),
#  ('반품', 4),
#  ('개월', 4),
#  ('종료', 4),
#  ('부자', 4),
#  ('되게', 3),
#  ('최대한', 3),
#  ('나쁘다', 3),
#  ('조연', 3),
#  ('중인', 3),
#  ('들이다', 3),
#  ('차지', 3),
#  ('까지는', 3),
#  ('바람', 3),
#  ('길다', 3),
#  ('아보', 3),
#  ('망설이다', 3),
#  ('물량', 3),
#  ('화려하다', 3),
#  ('오타쿠', 3),
#  ('부들부들하다', 3),
#  ('화면', 3),
#  ('화하다', 3),
#  ('겠다', 3),
#  ('애정', 3),
#  ('나서다', 3),
#  ('파다', 3),
#  ('전체', 3),
#  ('급하다', 3),
#  ('호구', 3),
#  ('세다', 3),
#  ('능력', 3),
#  ('고급스럽다', 3),
#  ('대기', 3),
#  ('중요하다', 3),
#  ('대처', 3),
#  ('다니다', 3),
#  ('어색하다', 3),
#  ('놀래다', 3),
#  ('건지다', 3),
#  ('택배', 3),
#  ('교환', 3),
#  ('이라도', 3),
#  ('상자', 3),
#  ('사지', 3),
#  ('띵작', 3),
#  ('사진', 3),
#  ('성장', 3),
#  ('달라지다', 3),
#  ('민감하다', 3),
#  ('입문', 3),
#  ('매끄럽다', 3),
#  ('특별판', 3),
#  ('대단하다', 3),
#  ('공식', 3),
#  ('절대', 3),
#  ('그다음', 3),
#  ('재앙', 3),
#  ('게시', 3),
#  ('긁다', 3),
#  ('힘드다', 3),
#  ('하자', 3),
#  ('동명', 3),
#  ('서적', 3),
#  ('거기', 3),
#  ('어가', 3),
#  ('모로', 3),
#  ('장목', 3),
#  ('성실하다', 3),
#  ('짐작', 3),
#  ('쏠쏠하다', 3),
#  ('창의', 3),
#  ('가정', 3),
#  ('안정감', 3),
#  ('책표지', 3),
#  ('달성', 3),
#  ('쭉쭉', 3),
#  ('현성', 3),
#  ('근육', 3),
#  ('포즈', 3),
#  ('굿즈같은', 3),
#  ('올라가다', 3),
#  ('한두', 3),
#  ('끼우다', 3),
#  ('경쟁', 3),
#  ('불만', 3),
#  ('쿠키', 3),
#  ('실패', 3),
#  ('든지', 3),
#  ('정독', 3),
#  ('클래스', 3),
#  ('각오', 3),
#  ('이지혜', 3),
#  ('꿀잼', 3),
#  ('이입', 3),
#  ('재수없다', 3),
#  ('색감', 3),
#  ('점도', 3),
#  ('거리', 3),
#  ('150', 3),
#  ('내놓다', 3),
#  ('이기', 2),
#  ('파일', 2),
#  ('김남운', 2),
#  ('명운', 2),
#  ('스릴', 2),
#  ('이현성', 2),
#  ('오래', 2),
#  ('해내다', 2),
#  ('대사', 2),
#  ('반영', 2),
#  ('적절하다', 2),
#  ('서울', 2),
#  ('정이', 2),
#  ('크게', 2),
#  ('구경', 2),
#  ('후회되다', 2),
#  ('메시지', 2),
#  ('생소하다', 2),
#  ('여름', 2),
#  ('슬슬', 2),
#  ('도서', 2),
#  ('이전', 2),
#  ('이슈', 2),
#  ('해오다', 2),
#  ('만족감', 2),
#  ('빳빳', 2),
#  ('특전들', 2),
#  ('터지다', 2),
#  ('만화가', 2),
#  ('판도', 2),
#  ('변하다', 2),
#  ('흥미진진', 2),
#  ('적지', 2),
#  ('묵직하다', 2),
#  ('모시다', 2),
#  ('자리', 2),
#  ('작업', 2),
#  ('스킬', 2),
#  ('이상하다', 2),
#  ('포장', 2),
#  ('늘다', 2),
#  ('엊그제', 2),
#  ('아이돌', 2),
#  ('폭발', 2),
#  ('결과', 2),
#  ('언급', 2),
#  ('드네', 2),
#  ('질문', 2),
#  ('과는', 2),
#  ('배치', 2),
#  ('덕분', 2),
#  ('이용', 2),
#  ('바뀌다', 2),
#  ('흠집', 2),
#  ('미리', 2),
#  ('따로', 2),
#  ('풀리다', 2),
#  ('영업', 2),
#  ('제한', 2),
#  ('보들보들하다', 2),
#  ('어마어마하다', 2),
#  ('참다', 2),
#  ('이북', 2),
#  ('편입', 2),
#  ('치다', 2),
#  ('100', 2),
#  ('펼치다', 2),
#  ('최적화', 2),
#  ('부터는', 2),
#  ('단말', 2),
#  ('문제', 2),
#  ('노리다', 2),
#  ('단계', 2),
#  ('좀더', 2),
#  ('조만간', 2),
#  ('랜덤', 2),
#  ('커버', 2),
#  ('갖다', 2),
#  ('최근', 2),
#  ('파손', 2),
#  ('사양', 2),
#  ...]

# %%
#최소 횟수 이하 단어 확인 (20개이하)
for item, count in Counter(remove_stopwords).most_common():
    if count==21:
        print(item)
# Out:
# 야하다
# 빠지다
# 설화
# 출판사

# %%
from tqdm import tqdm, trange

#20개 이하 제거

minimum_count = 21
more_than_one_time= []
for i in tqdm(range(len(remove_stopwords))):
    tmp = remove_stopwords[i]
    if remove_stopwords.count(tmp) >= minimum_count:
        more_than_one_time.append(tmp)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 14008/14008 [00:15<00:00, 893.37it/s]

# %%
Counter(more_than_one_time).most_common()
# Out:
# [('웹툰', 557),
#  ('독자', 368),
#  ('소설', 333),
#  ('구매', 270),
#  ('단행본', 227),
#  ('전지적', 217),
#  ('그림', 183),
#  ('원작', 178),
#  ('작품', 137),
#  ('내용', 123),
#  ('전독시', 118),
#  ('재밌다', 116),
#  ('싱숑', 109),
#  ('소장', 109),
#  ('완결', 107),
#  ('표지', 93),
#  ('리뷰', 92),
#  ('이야기', 89),
#  ('작가', 87),
#  ('연재', 82),
#  ('캐릭터', 81),
#  ('좋아하다', 75),
#  ('사람', 75),
#  ('만화', 72),
#  ('세계', 72),
#  ('초판', 70),
#  ('기대', 69),
#  ('재미있다', 69),
#  ('주인공', 67),
#  ('빨리', 66),
#  ('기다리다', 64),
#  ('작화', 63),
#  ('마음', 63),
#  ('슬리피', 62),
#  ('카드', 60),
#  ('아쉽다', 58),
#  ('각색', 58),
#  ('글', 56),
#  ('구성', 56),
#  ('인기', 55),
#  ('처음', 52),
#  ('종이', 51),
#  ('부록', 48),
#  ('궁금하다', 48),
#  ('스토리', 47),
#  ('웹소설', 45),
#  ('기대하다', 45),
#  ('시작', 44),
#  ('그리다', 44),
#  ('취향', 43),
#  ('모으다', 42),
#  ('추천', 40),
#  ('회귀', 40),
#  ('살리다', 39),
#  ('다르다', 39),
#  ('새롭다', 39),
#  ('판타지', 39),
#  ('미디어', 38),
#  ('예쁘다', 38),
#  ('세트', 37),
#  ('김독자', 37),
#  ('에이템포', 36),
#  ('인물', 36),
#  ('재질', 36),
#  ('현실', 35),
#  ('상상', 34),
#  ('구입', 34),
#  ('얼른얼른', 34),
#  ('전개', 33),
#  ('사다', 33),
#  ('초반', 32),
#  ('한정판', 32),
#  ('세상', 31),
#  ('매력', 30),
#  ('유명하다', 30),
#  ('잘생기다', 30),
#  ('네이버', 29),
#  ('소장용', 29),
#  ('기분', 29),
#  ('얼른', 29),
#  ('유중혁', 28),
#  ('유일하다', 28),
#  ('느끼다', 27),
#  ('한정', 27),
#  ('편집', 27),
#  ('에디션', 27),
#  ('즐겁다', 26),
#  ('결말', 26),
#  ('중혁', 26),
#  ('탄탄하다', 26),
#  ('드디어', 26),
#  ('벌레', 25),
#  ('괜찮다', 25),
#  ('재미', 25),
#  ('표현', 25),
#  ('스트랩', 25),
#  ('소식', 24),
#  ('지르다', 24),
#  ('이쁘다', 24),
#  ('특전', 24),
#  ('스페셜', 24),
#  ('어여', 24),
#  ('만화책', 23),
#  ('확실하다', 23),
#  ('10년', 23),
#  ('가격', 23),
#  ('바라다', 23),
#  ('만족하다', 23),
#  ('포함', 22),
#  ('지하철', 22),
#  ('퀄리티', 22),
#  ('장르', 22),
#  ('만족스럽다', 22),
#  ('야하다', 21),
#  ('빠지다', 21),
#  ('설화', 21),
#  ('출판사', 21)]

# %%
def save_and_load(dataframe):
    DATA_IN_PATH="C:/Users/nirae/Desktop/주간프로젝트 깃허브 폴더(최종)/크롤링/data/" #최윤지 깃허브 경로
    FileName='yes24_review_total'
    dataframe.to_csv(DATA_IN_PATH+FileName+'.csv',header=0,sep=',')
    df=pd.read_csv(DATA_IN_PATH+FileName+'.csv',header=0,sep=',')
    df = df.dropna()
    df = df.drop_duplicates()
    df = df.reset_index(drop=True)
    return df

# %%
def load_stopwords():
    with open('stopwords.txt', 'r') as f:
        list_file = f.readlines()
    return list_file[0].split(",")

# %%
#한글, 숫자 표현만 남기기
def extract_word(text):
    hangul = re.compile('[^0-9가-힣]') 
    result = hangul.sub(' ', text) 
    return result

# %%
def make_wordlist(reviews,stopwords): #reviews = " ".join(data['Review'].tolist())
    print("리뷰들을 모아 분석하는 중입니다.....")
    #정규표현식 적용
    print("데이터 정제 중....")
    words = extract_word(reviews)
    #형태소 추출
    print("형태소 추출 중....")
    words = okt.morphs(words,stem=True)
    #한글자 제거
    print("한글자 제거 중....")
    words = [x for x in words if len(x)>1 or x=="글"]
    #불용어 제거
    print("불용어 제거 중....")
    words = [x for x in remove_one_word if x not in stopwords]
    #최소횟수 미만 제거
    print("의미있는 단어리스트 생성 중....")
    time.sleep(1)
    minimum_count = 20
    final = []
    for i in tqdm(range(len(words))):
        tmp = words[i]
        if words.count(tmp) >= minimum_count:
            final.append(tmp)
    return set(final) #조건을 만족하는 단어 리스트

# %%
def preprocess(text, word_list):
    text = extract_word(text)
    okt = Okt()
    text = okt.morphs(text, stem = True)
    text = [x for x in text if x in word_list]
    return text

# %%
word_lst=make_wordlist("".join(df['Review'].tolist()),stopwords)
# Out:
# 리뷰들을 모아 분석하는 중입니다.....
# 데이터 정제 중....
# 형태소 추출 중....
# 한글자 제거 중....
# 불용어 제거 중....
# 의미있는 단어리스트 생성 중....
# 100%|███████████████████████████████████████████████████████████████████████████| 14008/14008 [00:15<00:00, 888.56it/s]

# %%
Counter(more_than_one_time).most_common()
# Out:
# [('웹툰', 557),
#  ('독자', 368),
#  ('소설', 333),
#  ('구매', 270),
#  ('단행본', 227),
#  ('전지적', 217),
#  ('그림', 183),
#  ('원작', 178),
#  ('작품', 137),
#  ('내용', 123),
#  ('전독시', 118),
#  ('재밌다', 116),
#  ('싱숑', 109),
#  ('소장', 109),
#  ('완결', 107),
#  ('표지', 93),
#  ('리뷰', 92),
#  ('이야기', 89),
#  ('작가', 87),
#  ('연재', 82),
#  ('캐릭터', 81),
#  ('좋아하다', 75),
#  ('사람', 75),
#  ('만화', 72),
#  ('세계', 72),
#  ('초판', 70),
#  ('기대', 69),
#  ('재미있다', 69),
#  ('주인공', 67),
#  ('빨리', 66),
#  ('기다리다', 64),
#  ('작화', 63),
#  ('마음', 63),
#  ('슬리피', 62),
#  ('카드', 60),
#  ('아쉽다', 58),
#  ('각색', 58),
#  ('글', 56),
#  ('구성', 56),
#  ('인기', 55),
#  ('처음', 52),
#  ('종이', 51),
#  ('부록', 48),
#  ('궁금하다', 48),
#  ('스토리', 47),
#  ('웹소설', 45),
#  ('기대하다', 45),
#  ('시작', 44),
#  ('그리다', 44),
#  ('취향', 43),
#  ('모으다', 42),
#  ('추천', 40),
#  ('회귀', 40),
#  ('살리다', 39),
#  ('다르다', 39),
#  ('새롭다', 39),
#  ('판타지', 39),
#  ('미디어', 38),
#  ('예쁘다', 38),
#  ('세트', 37),
#  ('김독자', 37),
#  ('에이템포', 36),
#  ('인물', 36),
#  ('재질', 36),
#  ('현실', 35),
#  ('상상', 34),
#  ('구입', 34),
#  ('얼른얼른', 34),
#  ('전개', 33),
#  ('사다', 33),
#  ('초반', 32),
#  ('한정판', 32),
#  ('세상', 31),
#  ('매력', 30),
#  ('유명하다', 30),
#  ('잘생기다', 30),
#  ('네이버', 29),
#  ('소장용', 29),
#  ('기분', 29),
#  ('얼른', 29),
#  ('유중혁', 28),
#  ('유일하다', 28),
#  ('느끼다', 27),
#  ('한정', 27),
#  ('편집', 27),
#  ('에디션', 27),
#  ('즐겁다', 26),
#  ('결말', 26),
#  ('중혁', 26),
#  ('탄탄하다', 26),
#  ('드디어', 26),
#  ('벌레', 25),
#  ('괜찮다', 25),
#  ('재미', 25),
#  ('표현', 25),
#  ('스트랩', 25),
#  ('소식', 24),
#  ('지르다', 24),
#  ('이쁘다', 24),
#  ('특전', 24),
#  ('스페셜', 24),
#  ('어여', 24),
#  ('만화책', 23),
#  ('확실하다', 23),
#  ('10년', 23),
#  ('가격', 23),
#  ('바라다', 23),
#  ('만족하다', 23),
#  ('포함', 22),
#  ('지하철', 22),
#  ('퀄리티', 22),
#  ('장르', 22),
#  ('만족스럽다', 22),
#  ('야하다', 21),
#  ('빠지다', 21),
#  ('설화', 21),
#  ('출판사', 21)]

# %%
count=Counter(more_than_one_time)
print(count)
# Out:
# Counter({'웹툰': 557, '독자': 368, '소설': 333, '구매': 270, '단행본': 227, '전지적': 217, '그림': 183, '원작': 178, '작품': 137, '내용': 123, '전독시': 118, '재밌다': 116, '싱숑': 109, '소장': 109, '완결': 107, '표지': 93, '리뷰': 92, '이야기': 89, '작가': 87, '연재': 82, '캐릭터': 81, '좋아하다': 75, '사람': 75, '만화': 72, '세계': 72, '초판': 70, '기대': 69, '재미있다': 69, '주인공': 67, '빨리': 66, '기다리다': 64, '작화': 63, '마음': 63, '슬리피': 62, '카드': 60, '아쉽다': 58, '각색': 58, '글': 56, '구성': 56, '인기': 55, '처음': 52, '종이': 51, '부록': 48, '궁금하다': 48, '스토리': 47, '웹소설': 45, '기대하다': 45, '시작': 44, '그리다': 44, '취향': 43, '모으다': 42, '추천': 40, '회귀': 40, '살리다': 39, '다르다': 39, '새롭다': 39, '판타지': 39, '미디어': 38, '예쁘다': 38, '세트': 37, '김독자': 37, '에이템포': 36, '인물': 36, '재질': 36, '현실': 35, '상상': 34, '구입': 34, '얼른얼른': 34, '전개': 33, '사다': 33, '초반': 32, '한정판': 32, '세상': 31, '매력': 30, '유명하다': 30, '잘생기다': 30, '네이버': 29, '소장용': 29, '기분': 29, '얼른': 29, '유중혁': 28, '유일하다': 28, '느끼다': 27, '한정': 27, '편집': 27, '에디션': 27, '즐겁다': 26, '결말': 26, '중혁': 26, '탄탄하다': 26, '드디어': 26, '벌레': 25, '괜찮다': 25, '재미': 25, '표현': 25, '스트랩': 25, '소식': 24, '지르다': 24, '이쁘다': 24, '특전': 24, '스페셜': 24, '어여': 24, '만화책': 23, '확실하다': 23, '10년': 23, '가격': 23, '바라다': 23, '만족하다': 23, '포함': 22, '지하철': 22, '퀄리티': 22, '장르': 22, '만족스럽다': 22, '야하다': 21, '빠지다': 21, '설화': 21, '출판사': 21})

# %%
# tag2=count.most_common()
# taglist=pytagcloud.make_tags(tag2, maxsize=200)  # tag2데이터로 태그 생성
# print(taglist)

# %%
icon = Image.open('wc copy.png')    # 마스크가 될 이미지 불러오기 
plt.imshow(icon)
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

# %%
wc = WordCloud(font_path='malgun', 
               background_color='white',
#                colormap='Greens',
               width=1000, 
               height=1000, 
               scale=2.0, 
               max_font_size=300, 
               mask=mask)
gen = wc.generate_from_frequencies(count)
plt.figure(figsize=(10,10))       
plt.axis('off') 
plt.imshow(wc,interpolation='bilinear')
plt.figure()

# %%
gen.to_file('yes_24(okt).png')

# %%
df_test = pd.DataFrame(list(count.values()), count.keys()) 

df_test
# Out:
#        0
# 기대    69
# 웹툰   557
# 캐릭터   81
# 매력    30
# 살리다   39
# ..   ...
# 출판사   21
# 특전    24
# 스페셜   24
# 에디션   27
# 어여    24
#
# [117 rows x 1 columns]

# %%
result = df_test.sort_values([0], ascending=True)
head = result.tail(10)

# %%
head
# Out:
#        0
# 내용   123
# 작품   137
# 원작   178
# 그림   183
# 전지적  217
# 단행본  227
# 구매   270
# 소설   333
# 독자   368
# 웹툰   557

# %%
plt.style.use('ggplot')
head.plot(kind='barh', color='cornflowerblue', width=0.5, figsize=(10,10),fontsize=20 )

plt.title('YES24 중요 키워드 top10', fontsize=30 , loc ='center', pad=20)

# plt.legend(loc='best')
plt.xlabel('빈도수', size = 15)
plt.ylabel('키워드', size = 15)
plt.savefig('yes_24_keyword10.png')
# plt.show()

# %%
key_word='평균'
test = df[df['Review'].str.contains(key_word)]
#a=test.sample(frac=0.05) #원하는 % 만큼 추출
a=test.sample(n=10) #원하는 개수만큼 추출
print(a)
# Out:
#      Unnamed: 0                                             Review
# 153           7                   총 연재 횟수 3 149회평균 조회 수 1 9회평균 ...
# 309          42                   총 연재 횟수 3 149회평균 조회 수 1 9회평균 ...
# 323          56   드디어 전지적 독자 시점이 웹소설에서만 볼 수가 있었는데 이제는 만화책으로 출판이...
# 253          44   드디어 전지적 독자 시점이 웹소설에서만 볼 수가 있었는데 이제는 만화책으로 출판이...
# 381          50                   총 연재 횟수 3 149회평균 조회 수 1 9회평균 ...
# 142          37   드디어 전지적 독자 시점이 웹소설에서만 볼 수가 있었는데 이제는 만화책으로 출판이...
# 395          64   드디어 전지적 독자 시점이 웹소설에서만 볼 수가 있었는데 이제는 만화책으로 출판이...
# 20           20   드디어 전지적 독자 시점이 웹소설에서만 볼 수가 있었는데 이제는 만화책으로 출판이...
# 239          30                   총 연재 횟수 3 149회평균 조회 수 1 9회평균 ...
# 88           52    누적 조회 수 1억 뷰 레전드 판타지 웹 소설 마침내 웹툰으로 총 연재 횟수 3...
