# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from bs4 import BeautifulSoup as bs

import pandas as pd
import time

# %%
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)

# %%
service = Service(executable_path=ChromeDriverManager().install())

# %%
def get_comments(service, df, webtoon_id, episode_no):
    TIMEOUT = 1   
    driver = webdriver.Chrome(service=service)
    
    url = 'https://comic.naver.com/webtoon/detail?'
    episode_url = url + 'titleId=' + str(webtoon_id) + '&no='+str(episode_no)
    print(episode_url)
    driver.get(episode_url) # 새창 열기
    driver.implicitly_wait(TIMEOUT)
    
    # 댓글창에 해당하는 프레임 선택
    driver.switch_to.frame('commentIframe')
    
    # 수집 편의를 위한 클린봇 댓글 필터링 기능 해제
    # (클린봇이 부적절한 표현을 감지한 댓글입니다.) 제거
    driver.find_element(By.CLASS_NAME,'u_cbox_cleanbot_setbutton').click()
    time.sleep(0.4)
    driver.find_element(By.CLASS_NAME,'u_cbox_layer_cleanbot2_checkbox').click()
    time.sleep(0.4)
    driver.find_element(By.CLASS_NAME,'u_cbox_layer_cleanbot2_extrabtn').click()
    time.sleep(0.4)

    # 전체 댓글 클릭
    driver.find_element(By.CSS_SELECTOR,'#cbox_module > div > div.u_cbox_view_comment > a').click()
    time.sleep(1)
    
    # "맨뒤" 클릭하여 전체 페이지 수 조회
    driver.find_element(By.CSS_SELECTOR,'#cbox_module > div > div.u_cbox_paginate > div > a.u_cbox_next.u_cbox_next_end > span.u_cbox_cnt_page').click()
    time.sleep(1)
    strong = driver.find_element(By.CSS_SELECTOR,'#cbox_module > div > div.u_cbox_paginate > div > strong')
    num_pages = strong.get_attribute('data-param')  # class_ = a.get_attribute('class')
    print("num_pages: ", num_pages)     
    
    # "맨앞" 으로 이동
    driver.find_element(By.CSS_SELECTOR,'#cbox_module > div > div.u_cbox_paginate > div > a.u_cbox_pre.u_cbox_pre_end > span.u_cbox_cnt_page').click()
    time.sleep(1)
    
    # 0 ~ 818
    for page in range(int(num_pages)):

        #최근 열린 탭으로 전환
        driver.switch_to.window(driver.window_handles[-1]) 
        driver.switch_to.frame("commentIframe")
        soup = bs(driver.page_source,"html.parser")

        # 날짜 추출
        dates = soup.findAll("span", {"class":["u_cbox_date"]})
        dates = [date.text for date in dates]        

        # 삭제된 댓글 제외하고 모든 댓글 추출
        reviews = soup.findAll("span", {"class":["u_cbox_contents"]})
        reviews = [review.get_text() for review in reviews]

        df_page = pd.DataFrame(data=[], columns=['에피소드','날짜','댓글'])
        df_page['날짜'] = dates
        df_page['댓글'] = reviews
        df_page['에피소드'] = df_page['에피소드'].fillna(episode_no) 
        
        df = pd.concat([df,df_page])      
        print(page+1, " page Done.")        

        if (page+1) == int(num_pages):
            return df
        
        # 다음 페이지로 이동
        driver.find_element(By.CSS_SELECTOR, "#cbox_module > div > div.u_cbox_paginate > div > strong + a").click()        
        time.sleep(0.4)
    driver.close()
    return df

df = pd.DataFrame(data=[], columns=['에피소드','날짜','댓글'])
df = get_comments(service, df, 747269, 1) # 전지적 독자 시점 - 에피소드 1
df

df.to_csv("전체댓글.csv",index = False)
# Out:
# https://comic.naver.com/webtoon/detail?titleId=747269&no=1
# num_pages:  819
# 1  page Done.
# 2  page Done.
# 3  page Done.
# 4  page Done.
# 5  page Done.
# 6  page Done.
# 7  page Done.
# 8  page Done.
# 9  page Done.
# 10  page Done.
# 11  page Done.
# 12  page Done.
# 13  page Done.
# 14  page Done.
# 15  page Done.
# 16  page Done.
# 17  page Done.
# 18  page Done.
# 19  page Done.
# 20  page Done.
# 21  page Done.
# 22  page Done.
# 23  page Done.
# 24  page Done.
# 25  page Done.
# 26  page Done.
# 27  page Done.
# 28  page Done.
# 29  page Done.
# 30  page Done.
# 31  page Done.
# 32  page Done.
# 33  page Done.
# 34  page Done.
# 35  page Done.
# 36  page Done.
# 37  page Done.
# 38  page Done.
# 39  page Done.
# 40  page Done.
# 41  page Done.
# 42  page Done.
# 43  page Done.
# 44  page Done.
# 45  page Done.
# 46  page Done.
# 47  page Done.
# 48  page Done.
# 49  page Done.
# 50  page Done.
# 51  page Done.
# 52  page Done.
# 53  page Done.
# 54  page Done.
# 55  page Done.
# 56  page Done.
# 57  page Done.
# 58  page Done.
# 59  page Done.
# 60  page Done.
# 61  page Done.
# 62  page Done.
# 63  page Done.
# 64  page Done.
# 65  page Done.
# 66  page Done.
# 67  page Done.
# 68  page Done.
# 69  page Done.
# 70  page Done.
# 71  page Done.
# 72  page Done.
# 73  page Done.
# 74  page Done.
# 75  page Done.
# 76  page Done.
# 77  page Done.
# 78  page Done.
# 79  page Done.
# 80  page Done.
# 81  page Done.
# 82  page Done.
# 83  page Done.
# 84  page Done.
# 85  page Done.
# 86  page Done.
# 87  page Done.
# 88  page Done.
# 89  page Done.
# 90  page Done.
# 91  page Done.
# 92  page Done.
# 93  page Done.
# 94  page Done.
# 95  page Done.
# 96  page Done.
# 97  page Done.
# 98  page Done.
# 99  page Done.
# 100  page Done.
# 101  page Done.
# 102  page Done.
# 103  page Done.
# 104  page Done.
# 105  page Done.
# 106  page Done.
# 107  page Done.
# 108  page Done.
# 109  page Done.
# 110  page Done.
# 111  page Done.
# 112  page Done.
# 113  page Done.
# 114  page Done.
# 115  page Done.
# 116  page Done.
# 117  page Done.
# 118  page Done.
# 119  page Done.
# 120  page Done.
# 121  page Done.
# 122  page Done.
# 123  page Done.
# 124  page Done.
# 125  page Done.
# 126  page Done.
# 127  page Done.
# 128  page Done.
# 129  page Done.
# 130  page Done.
# 131  page Done.
# 132  page Done.
# 133  page Done.
# 134  page Done.
# 135  page Done.
# 136  page Done.
# 137  page Done.
# 138  page Done.
# 139  page Done.
# 140  page Done.
# 141  page Done.
# 142  page Done.
# 143  page Done.
# 144  page Done.
# 145  page Done.
# 146  page Done.
# 147  page Done.
# 148  page Done.
# 149  page Done.
# 150  page Done.
# 151  page Done.
# 152  page Done.
# 153  page Done.
# 154  page Done.
# 155  page Done.
# 156  page Done.
# 157  page Done.
# 158  page Done.
# 159  page Done.
# 160  page Done.
# 161  page Done.
# 162  page Done.
# 163  page Done.
# 164  page Done.
# 165  page Done.
# 166  page Done.
# 167  page Done.
# 168  page Done.
# 169  page Done.
# 170  page Done.
# 171  page Done.
# 172  page Done.
# 173  page Done.
# 174  page Done.
# 175  page Done.
# 176  page Done.
# 177  page Done.
# 178  page Done.
# 179  page Done.
# 180  page Done.
# 181  page Done.
# 182  page Done.
# 183  page Done.
# 184  page Done.
# 185  page Done.
# 186  page Done.
# 187  page Done.
# 188  page Done.
# 189  page Done.
# 190  page Done.
# 191  page Done.
# 192  page Done.
# 193  page Done.
# 194  page Done.
# 195  page Done.
# 196  page Done.
# 197  page Done.
# 198  page Done.
# 199  page Done.
# 200  page Done.
# 201  page Done.
# 202  page Done.
# 203  page Done.
# 204  page Done.
# 205  page Done.
# 206  page Done.
# 207  page Done.
# 208  page Done.
# 209  page Done.
# 210  page Done.
# 211  page Done.
# 212  page Done.
# 213  page Done.
# 214  page Done.
# 215  page Done.
# 216  page Done.
# 217  page Done.
# 218  page Done.
# 219  page Done.
# 220  page Done.
# 221  page Done.
# 222  page Done.
# 223  page Done.
# 224  page Done.
# 225  page Done.
# 226  page Done.
# 227  page Done.
# 228  page Done.
# 229  page Done.
# 230  page Done.
# 231  page Done.
# 232  page Done.
# 233  page Done.
# 234  page Done.
# 235  page Done.
# 236  page Done.
# 237  page Done.
# 238  page Done.
# 239  page Done.
# 240  page Done.
# 241  page Done.
# 242  page Done.
# 243  page Done.
# 244  page Done.
# 245  page Done.
# 246  page Done.
# 247  page Done.
# 248  page Done.
# 249  page Done.
# 250  page Done.
# 251  page Done.
# 252  page Done.
# 253  page Done.
# 254  page Done.
# 255  page Done.
# 256  page Done.
# 257  page Done.
# 258  page Done.
# 259  page Done.
# 260  page Done.
# 261  page Done.
# 262  page Done.
# 263  page Done.
# 264  page Done.
# 265  page Done.
# 266  page Done.
# 267  page Done.
# 268  page Done.
# 269  page Done.
# 270  page Done.
# 271  page Done.
# 272  page Done.
# 273  page Done.
# 274  page Done.
# 275  page Done.
# 276  page Done.
# 277  page Done.
# 278  page Done.
# 279  page Done.
# 280  page Done.
# 281  page Done.
# 282  page Done.
# 283  page Done.
# 284  page Done.
# 285  page Done.
# 286  page Done.
# 287  page Done.
# 288  page Done.
# 289  page Done.
# 290  page Done.
# 291  page Done.
# 292  page Done.
# 293  page Done.
# 294  page Done.
# 295  page Done.
# 296  page Done.
# 297  page Done.
# 298  page Done.
# 299  page Done.
# 300  page Done.
# 301  page Done.
# 302  page Done.
# 303  page Done.
# 304  page Done.
# 305  page Done.
# 306  page Done.
# 307  page Done.
# 308  page Done.
# 309  page Done.
# 310  page Done.
# 311  page Done.
# 312  page Done.
# 313  page Done.
# 314  page Done.
# 315  page Done.
# 316  page Done.
# 317  page Done.
# 318  page Done.
# 319  page Done.
# 320  page Done.
# 321  page Done.
# 322  page Done.
# 323  page Done.
# 324  page Done.
# 325  page Done.
# 326  page Done.
# 327  page Done.
# 328  page Done.
# 329  page Done.
# 330  page Done.
# 331  page Done.
# 332  page Done.
# 333  page Done.
# 334  page Done.
# 335  page Done.
# 336  page Done.
# 337  page Done.
# 338  page Done.
# 339  page Done.
# 340  page Done.
# 341  page Done.
# 342  page Done.
# 343  page Done.
# 344  page Done.
# 345  page Done.
# 346  page Done.
# 347  page Done.
# 348  page Done.
# 349  page Done.
# 350  page Done.
# 351  page Done.
# 352  page Done.
# 353  page Done.
# 354  page Done.
# 355  page Done.
# 356  page Done.
# 357  page Done.
# 358  page Done.
# 359  page Done.
# 360  page Done.
# 361  page Done.
# 362  page Done.
# 363  page Done.
# 364  page Done.
# 365  page Done.
# 366  page Done.
# 367  page Done.
# 368  page Done.
# 369  page Done.
# 370  page Done.
# 371  page Done.
# 372  page Done.
# 373  page Done.
# 374  page Done.
# 375  page Done.
# 376  page Done.
# 377  page Done.
# 378  page Done.
# 379  page Done.
# 380  page Done.
# 381  page Done.
# 382  page Done.
# 383  page Done.
# 384  page Done.
# 385  page Done.
# 386  page Done.
# 387  page Done.
# 388  page Done.
# 389  page Done.
# 390  page Done.
# 391  page Done.
# 392  page Done.
# 393  page Done.
# 394  page Done.
# 395  page Done.
# 396  page Done.
# 397  page Done.
# 398  page Done.
# 399  page Done.
# 400  page Done.
# 401  page Done.
# 402  page Done.
# 403  page Done.
# 404  page Done.
# 405  page Done.
# 406  page Done.
# 407  page Done.
# 408  page Done.
# 409  page Done.
# 410  page Done.
# 411  page Done.
# 412  page Done.
# 413  page Done.
# 414  page Done.
# 415  page Done.
# 416  page Done.
# 417  page Done.
# 418  page Done.
# 419  page Done.
# 420  page Done.
# 421  page Done.
# 422  page Done.
# 423  page Done.
# 424  page Done.
# 425  page Done.
# 426  page Done.
# 427  page Done.
# 428  page Done.
# 429  page Done.
# 430  page Done.
# 431  page Done.
# 432  page Done.
# 433  page Done.
# 434  page Done.
# 435  page Done.
# 436  page Done.
# 437  page Done.
# 438  page Done.
# 439  page Done.
# 440  page Done.
# 441  page Done.
# 442  page Done.
# 443  page Done.
# 444  page Done.
# 445  page Done.
# 446  page Done.
# 447  page Done.
# 448  page Done.
# 449  page Done.
# 450  page Done.
# 451  page Done.
# 452  page Done.
# 453  page Done.
# 454  page Done.
# 455  page Done.
# 456  page Done.
# 457  page Done.
# 458  page Done.
# 459  page Done.
# 460  page Done.
# 461  page Done.
# 462  page Done.
# 463  page Done.
# 464  page Done.
# 465  page Done.
# 466  page Done.
# 467  page Done.
# 468  page Done.
# 469  page Done.
# 470  page Done.
# 471  page Done.
# 472  page Done.
# 473  page Done.
# 474  page Done.
# 475  page Done.
# 476  page Done.
# 477  page Done.
# 478  page Done.
# 479  page Done.
# 480  page Done.
# 481  page Done.
# 482  page Done.
# 483  page Done.
# 484  page Done.
# 485  page Done.
# 486  page Done.
# 487  page Done.
# 488  page Done.
# 489  page Done.
# 490  page Done.
# 491  page Done.
# 492  page Done.
# 493  page Done.
# 494  page Done.
# 495  page Done.
# 496  page Done.
# 497  page Done.
# 498  page Done.
# 499  page Done.
# 500  page Done.
# 501  page Done.
# 502  page Done.
# 503  page Done.
# 504  page Done.
# 505  page Done.
# 506  page Done.
# 507  page Done.
# 508  page Done.
# 509  page Done.
# 510  page Done.
# 511  page Done.
# 512  page Done.
# 513  page Done.
# 514  page Done.
# 515  page Done.
# 516  page Done.
# 517  page Done.
# 518  page Done.
# 519  page Done.
# 520  page Done.
# 521  page Done.
# 522  page Done.
# 523  page Done.
# 524  page Done.
# 525  page Done.
# 526  page Done.
# 527  page Done.
# 528  page Done.
# 529  page Done.
# 530  page Done.
# 531  page Done.
# 532  page Done.
# 533  page Done.
# 534  page Done.
# 535  page Done.
# 536  page Done.
# 537  page Done.
# 538  page Done.
# 539  page Done.
# 540  page Done.
# 541  page Done.
# 542  page Done.
# 543  page Done.
# 544  page Done.
# 545  page Done.
# 546  page Done.
# 547  page Done.
# 548  page Done.
# 549  page Done.
# 550  page Done.
# 551  page Done.
# 552  page Done.
# 553  page Done.
# 554  page Done.
# 555  page Done.
# 556  page Done.
# 557  page Done.
# 558  page Done.
# 559  page Done.
# 560  page Done.
# 561  page Done.
# 562  page Done.
# 563  page Done.
# 564  page Done.
# 565  page Done.
# 566  page Done.
# 567  page Done.
# 568  page Done.
# 569  page Done.
# 570  page Done.
# 571  page Done.
# 572  page Done.
# 573  page Done.
# 574  page Done.
# 575  page Done.
# 576  page Done.
# 577  page Done.
# 578  page Done.
# 579  page Done.
# 580  page Done.
# 581  page Done.
# 582  page Done.
# 583  page Done.
# 584  page Done.
# 585  page Done.
# 586  page Done.
# 587  page Done.
# 588  page Done.
# 589  page Done.
# 590  page Done.
# 591  page Done.
# 592  page Done.
# 593  page Done.
# 594  page Done.
# 595  page Done.
# 596  page Done.
# 597  page Done.
# 598  page Done.
# 599  page Done.
# 600  page Done.
# 601  page Done.
# 602  page Done.
# 603  page Done.
# 604  page Done.
# 605  page Done.
# 606  page Done.
# 607  page Done.
# 608  page Done.
# 609  page Done.
# 610  page Done.
# 611  page Done.
# 612  page Done.
# 613  page Done.
# 614  page Done.
# 615  page Done.
# 616  page Done.
# 617  page Done.
# 618  page Done.
# 619  page Done.
# 620  page Done.
# 621  page Done.
# 622  page Done.
# 623  page Done.
# 624  page Done.
# 625  page Done.
# 626  page Done.
# 627  page Done.
# 628  page Done.
# 629  page Done.
# 630  page Done.
# 631  page Done.
# 632  page Done.
# 633  page Done.
# 634  page Done.
# 635  page Done.
# 636  page Done.
# 637  page Done.
# 638  page Done.
# 639  page Done.
# 640  page Done.
# 641  page Done.
# 642  page Done.
# 643  page Done.
# 644  page Done.
# 645  page Done.
# 646  page Done.
# 647  page Done.
# 648  page Done.
# 649  page Done.
# 650  page Done.
# 651  page Done.
# 652  page Done.
# 653  page Done.
# 654  page Done.
# 655  page Done.
# 656  page Done.
# 657  page Done.
# 658  page Done.
# 659  page Done.
# 660  page Done.
# 661  page Done.
# 662  page Done.
# 663  page Done.
# 664  page Done.
# 665  page Done.
# 666  page Done.
# 667  page Done.
# 668  page Done.
# 669  page Done.
# 670  page Done.
# 671  page Done.
# 672  page Done.
# 673  page Done.
# 674  page Done.
# 675  page Done.
# 676  page Done.
# 677  page Done.
# 678  page Done.
# 679  page Done.
# 680  page Done.
# 681  page Done.
# 682  page Done.
# 683  page Done.
# 684  page Done.
# 685  page Done.
# 686  page Done.
# 687  page Done.
# 688  page Done.
# 689  page Done.
# 690  page Done.
# 691  page Done.
# 692  page Done.
# 693  page Done.
# 694  page Done.
# 695  page Done.
# 696  page Done.
# 697  page Done.
# 698  page Done.
# 699  page Done.
# 700  page Done.
# 701  page Done.
# 702  page Done.
# 703  page Done.
# 704  page Done.
# 705  page Done.
# 706  page Done.
# 707  page Done.
# 708  page Done.
# 709  page Done.
# 710  page Done.
# 711  page Done.
# 712  page Done.
# 713  page Done.
# 714  page Done.
# 715  page Done.
# 716  page Done.
# 717  page Done.
# 718  page Done.
# 719  page Done.
# 720  page Done.
# 721  page Done.
# 722  page Done.
# 723  page Done.
# 724  page Done.
# 725  page Done.
# 726  page Done.
# 727  page Done.
# 728  page Done.
# 729  page Done.
# 730  page Done.
# 731  page Done.
# 732  page Done.
# 733  page Done.
# 734  page Done.
# 735  page Done.
# 736  page Done.
# 737  page Done.
# 738  page Done.
# 739  page Done.
# 740  page Done.
# 741  page Done.
# 742  page Done.
# 743  page Done.
# 744  page Done.
# 745  page Done.
# 746  page Done.
# 747  page Done.
# 748  page Done.
# 749  page Done.
# 750  page Done.
# 751  page Done.
# 752  page Done.
# 753  page Done.
# 754  page Done.
# 755  page Done.
# 756  page Done.
# 757  page Done.
# 758  page Done.
# 759  page Done.
# 760  page Done.
# 761  page Done.
# 762  page Done.
# 763  page Done.
# 764  page Done.
# 765  page Done.
# 766  page Done.
# 767  page Done.
# 768  page Done.
# 769  page Done.
# 770  page Done.
# 771  page Done.
# 772  page Done.
# 773  page Done.
# 774  page Done.
# 775  page Done.
# 776  page Done.
# 777  page Done.
# 778  page Done.
# 779  page Done.
# 780  page Done.
# 781  page Done.
# 782  page Done.
# 783  page Done.
# 784  page Done.
# 785  page Done.
# 786  page Done.
# 787  page Done.
# 788  page Done.
# 789  page Done.
# 790  page Done.
# 791  page Done.
# 792  page Done.
# 793  page Done.
# 794  page Done.
# 795  page Done.
# 796  page Done.
# 797  page Done.
# 798  page Done.
# 799  page Done.
# 800  page Done.
# 801  page Done.
# 802  page Done.
# 803  page Done.
# 804  page Done.
# 805  page Done.
# 806  page Done.
# 807  page Done.
# 808  page Done.
# 809  page Done.
# 810  page Done.
# 811  page Done.
# 812  page Done.
# 813  page Done.
# 814  page Done.
# 815  page Done.
# 816  page Done.
# 817  page Done.
# 818  page Done.
# 819  page Done.

# %%
df
# Out:
#    에피소드                날짜                                                 댓글
# 0     1             48분 전                                        작가님도 결말 알잖씀
# 1     1             1시간 전  읽기 전****** 전독시 대댓글 보며 스포 안 당하는 법 ******\n대댓글 창...
# 2     1             1시간 전                                       김독자못생긴설정아니엇나
# 3     1              2일 전                                       8번째 정주행 시작~!
# 4     1              2일 전               3000화 넘는 소설이 몇년뒤엔 탄생할지도..ㅋㅋOOO의 화산귀환
# ..  ...               ...                                                ...
# 10    1  2020-05-26 23:00                                            독자야 사랑해
# 11    1  2020-05-26 23:00                                                ㅠㅠㅠ
# 12    1  2020-05-26 23:00                                         여기가 내 무덤인가
# 13    1  2020-05-26 23:00                                                  와
# 14    1  2020-05-26 23:00        올타임 레전드 1위 웹소설 전지적 독자 시점의 네이버 웹툰 입성을 축하합니다!
#
# [12246 rows x 3 columns]
