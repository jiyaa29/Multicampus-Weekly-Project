# %%
import os
import pandas as pd 
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_columns", 1000)

# %%
DEVELOPER_KEY = 'AIzaSyDdsDR6Yvb0shBMTPPg_F15ZH3Ye90vpuo'
YOUTUBE_API_SERVICE_NAME="youtube"
YOUTUBE_API_VERSION="v3"
youtube = build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
# Sample 1
# Omniscient Reader (Official Trailer) | WEBTOON
# https://www.youtube.com/watch?v=8OHzcTtoLo4&ab_channel=WEBTOON

video_id = '8OHzcTtoLo4'
title = 'Omniscient Reader (Official Trailer)'
comments = []
results = youtube.commentThreads().list(
    videoId = video_id,
    order='time',
    part = 'snippet',
    textFormat='plainText',
    maxResults = 100 # default 20
    ).execute()

# %%
# Sample 2
# 한국 웹툰, 제2의 해리포터가 될 수 있을까?
# https://www.youtube.com/watch?v=5z1N5TRNchI&ab_channel=%EC%8A%88%EC%B9%B4%EC%9B%94%EB%93%9C

video_id = '5z1N5TRNchI'
title = '한국 웹툰, 제2의 해리포터가 될 수 있을까'
comments = []
results = youtube.commentThreads().list(
    videoId = video_id,
    order='time',
    part = 'snippet',
    textFormat='plainText',
    maxResults = 100
    ).execute()

# %%
while results:
    for item in results['items']:
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment)
        
    if 'nextPageToken' in results:
            pageToken = results['nextPageToken']
            results = youtube.commentThreads().list(
                videoId = 'X7-aZpsnw5M',
                order='time',
                part = 'snippet',
                textFormat='plainText',
                pageToken = pageToken,
                maxResults = 100
                ).execute()
    else:
        break

# %%
df = pd.DataFrame(comments, columns =['Review'])
df
# Out:
#                                                 Review
# 0    Read Omniscient Reader now:\r\nhttps://bit.ly/...
# 1    "who are you?"\n"I'm just a reader"\nMe : then...
# 2                                             :"))))))
# 3                            Han sooyong is the writer
# 4    I dont really read novel, specially Korean one...
# 5    I just finished reading chapter 43, to me, it ...
# 6    This is probably the best official webtoon tra...
# 7                    Will get animation or something 😁
# 8    A song that really suits this webtoon/novel is...
# 9    This NEEDS to be an anime so  would without a ...
# 10                             Yeah. I'm just a Reader
# 11                                                cool
# 12                   wow! I am reading this manga now!
# 13   I'm dying of  curiousity. What actually is Kim...
# 14   The contellation, Conie, recommends everyone t...
# 15   i read this webtoon months ago and finally dec...
# ...

# %%
comments_str = ' '.join(comments)
print(comments_str)
# Out:
# Read Omniscient Reader now:
# https://bit.ly/3j3IWGm "who are you?"
# "I'm just a reader"
# ...

# %%
# ave as string
DATA_PATH = './data/'
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)
filepath = '{title}_{video_id}.txt'.format(title=title,video_id=video_id)
f = open(DATA_PATH + filepath, 'w')
f.write(comments_str)
f.close()

print(filepath + " saved.")
# Out:
# Omniscient Reader (Official Trailer)_8OHzcTtoLo4.txt saved.
